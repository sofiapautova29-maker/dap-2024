# %% [markdown]
# <a href="https://colab.research.google.com/github/sofiapautova29-maker/dap-2024/blob/main/les01/rep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %% [markdown]
# ### Лабораторная работа №1
# Подготовка среды для анализа данных
# Выполнила: Паутова Софья
# Группа: УСИС-25-4

# Цель работы: Настройка рабочей среды для анализа данных с использованием GitHub и Google Colab, изучение основных инструментов и принципов работы в Jupyter Notebook.

# Выполненные задачи:
# 1. Создание учетной записи GitHub
# Учетная запись GitHub успешно создана с логином: **sofiapautova29-maker**
# %% [markdown
# ### 2. Форк репозитория
# Выполнен форк оригинального репозитория:
# - Оригинал: https://github.com/chebotarevsa/dap-2024
# - Мой форк: https://github.com/sofiapautova29-maker/dap-2024

# %% [markdown]
# ### 3. Создание учетной записи в Google Colab
# Учетная запись Google Colab создана и привязана к аккаунту Google.

# %% [markdown]
# ### 4. Настройка интеграции Google Colab и GitHub
# Интеграция настроена через:
# 1. Авторизацию в GitHub из Google Colab
# 2. Предоставление необходимых разрешений
# 3. Настройку сохранения notebook'ов напрямую в репозиторий
# **Результат:** Возможность сохранения этого файла напрямую в GitHub через меню "Файл → Сохранить копию на GitHub"

# %% [markdown]
# ### 5. Создание отчета в Google Colab
# Данный отчет создан в формате Jupyter Notebook с использованием:
# - Markdown ячеек для оформления текста
# - Кодовых ячеек для демонстрации примеров
# - Заголовков различных уровней
# - Форматированного текста

# %% [markdown]
# ### 6. Сохранение отчета в репозиторий
# Файл будет сохранен в директории `./les01` моего репозитория GitHub.

# %% [markdown]
# ### 7. Создание Pull Request
# После сохранения файла будет создан Pull Request в оригинальный репозиторий с названием:
# **"1 УСИС-25-4 Паутова Софья"**

# %% [markdown]
# ### 8. Сдача работы
# Работа сдана в системе "Пегас" со ссылкой на созданный Pull Request.

# %% [markdown]
# ## Ответы на контрольные вопросы

# %% [markdown]
# ### 1. Типы ячеек в Jupyter Notebook
# В Jupyter Notebook существуют три основных типа ячеек:
# 1. **Code cells** (ячейки кода) — для написания и выполнения программного кода
# 2. **Markdown cells** (текстовые ячейки) — для оформления текста с использованием Markdown
# 3. **Raw cells** (сырые ячейки) — для неформатированного текста

# %% [markdown]
# ### 2. Как с помощью Markdown сформировать иерархический список?
# Используя отступы и различные маркеры:
#
# ```markdown
# - Элемент 1
#   - Подэлемент 1.1
#     - Подподэлемент 1.1.1
#   - Подэлемент 1.2
# - Элемент 2
# ```
#
# **Пример:**
# - Анализ данных
#   - Сбор данных
#     - Из API
#     - Из базы данных
#   - Очистка данных
# - Визуализация

# %% [markdown]
# ### 3. Как с помощью Markdown оформить цитату?
# Используя символ `>`:
#
# ```markdown
# > Это обычная цитата.
# > Она может занимать несколько строк.
#
# >> Это вложенная цитата.
# >
# > Возврат к основному уровню.
# ```

# %% [markdown]
# > *Пример цитаты:*
# > "Данные — это новая нефть."
# > — Клайв Хамби

# %% [markdown]
# ### 4. Как в текстовую ячейку вставить отформатированный блок кода?
# С помощью тройных обратных кавычек:
#
# ````markdown
# ```python
# # Пример кода на Python
# def hello():
#     print("Hello, World!")
#
# hello()
# ```
# ````

# %% [markdown]
# ### 5. Сколько уровней заголовка существует в Markdown?
# В Markdown существует **6 уровней заголовков**:
#
# ```markdown
# # Заголовок 1 уровня (самый крупный)
# ## Заголовок 2 уровня
# ### Заголовок 3 уровня
# #### Заголовок 4 уровня
# ##### Заголовок 5 уровня
# ###### Заголовок 6 уровня (самый мелкий)
# ```

# %% [markdown]
# ### 6. Шаги процесса анализа данных
#
# Основные шаги процесса анализа данных по методологии CRISP-DM:
#
# 1. **Business Understanding** (Понимание бизнес-задачи)
# 2. **Data Understanding** (Изучение данных)
# 3. **Data Preparation** (Подготовка данных)
# 4. **Modeling** (Моделирование)
# 5. **Evaluation** (Оценка)
# 6. **Deployment** (Внедрение)
#
# **Подробно о Data Preparation:**
# Это критически важный этап, занимающий до 80% времени анализа. Включает:
# - **Очистку данных**: удаление дубликатов, обработка пропусков и выбросов
# - **Трансформацию**: нормализация, масштабирование, кодирование категориальных переменных
# - **Создание признаков**: генерация новых переменных на основе существующих
# - **Разделение данных**: на обучающую, валидационную и тестовую выборки
#
# Качество подготовки данных напрямую определяет успех всего проекта анализа.

# %% [markdown]
# ### 7. Типы данных
#
# Основные типы данных в анализе:
#
# 1. **Числовые данные**
#    - Дискретные (целые числа)
#    - Непрерывные (вещественные числа)
#
# 2. **Категориальные данные**
#    - Номинальные (без порядка: цвета, города)
#    - Порядковые (с естественным порядком: уровни образования)
#
# 3. **Текстовые данные**
# 4. **Временные ряды**
# 5. **Геопространственные данные**
#
# **Подробно о категориальных данных:**
# Категориальные данные представляют качественные характеристики объектов. Особенности:
# - **Номинальные данные**: нет математического порядка (пример: цвета светофора)
# - **Порядковые данные**: есть естественный порядок (пример: уровни образования: школа < бакалавр < магистр)
#
# **Методы обработки:**
# - One-Hot Encoding (для номинальных данных)
# - Label Encoding (для порядковых данных)
# - Target Encoding
#
# **Пример в Python:**
#

# %%
# Пример работы с категориальными данными
import pandas as pd

# Создание датафрейма с категориальными данными
cat_data = pd.DataFrame({
    'Имя': ['Анна', 'Борис', 'Виктория'],
    'Цвет_глаз': ['карие', 'голубые', 'зеленые'],  # номинальные
    'Образование': ['бакалавр', 'магистр', 'школа']  # порядковые
})

print("Исходные данные:")
print(cat_data)

# One-Hot Encoding для номинальных данных
eye_dummies = pd.get_dummies(cat_data['Цвет_глаз'], prefix='глаза')
print("\nOne-Hot Encoding для цвета глаз:")
print(eye_dummies)

# Label Encoding для порядковых данных (вручную)
education_order = {'школа': 1, 'бакалавр': 2, 'магистр': 3}
cat_data['Образование_код'] = cat_data['Образование'].map(education_order)
print("\nLabel Encoding для образования:")
print(cat_data[['Имя', 'Образование', 'Образование_код']])

# %% [markdown]
# ### 8. Что такое Jupyter Notebook, для чего используется?
#
# **Jupyter Notebook** — это интерактивная веб-среда для создания и совместного использования документов, содержащих:
# - Живой код (Python, R, Julia и др.)
# - Визуализации (графики, диаграммы)
# - Текстовые пояснения (Markdown, LaTeX)
# - Мультимедиа
#
# **Основные применения:**
# 1. **Анализ данных и машинное обучение**
# 2. **Научные исследования и вычисления**
# 3. **Прототипирование и разработка**
# 4. **Обучение и преподавание**
# 5. **Создание воспроизводимых отчетов**
# 6. **Интерактивная визуализация**
#
# **Преимущества:**
# - Интерактивность (код выполняется и результат виден сразу)
# - Воспроизводимость (легко повторить анализ)
# - Документирование (код и объяснения в одном месте)
# - Поддержка различных языков

# %% [markdown]
# ### 9. Почему Python популярен для анализа данных?
#
# Python стал стандартом де-факто для анализа данных благодаря:
#
# 1. **Богатой экосистеме библиотек**:
#    - `pandas` — обработка табличных данных
#    - `numpy` — численные вычисления
#    - `matplotlib`, `seaborn` — визуализация
#    - `scikit-learn` — машинное обучение
#    - `tensorflow`, `pytorch` — глубокое обучение
#
# 2. **Простоте и читаемости** синтаксиса
# 3. **Большому и активному сообществу**
# 4. **Кроссплатформенности** (работает везде)
# 5. **Бесплатности** и открытости
# 6. **Интеграции** с другими инструментами и языками
# 7. **Поддержке различных парадигм** программирования
# 8. **Хорошей производительности** (за счет оптимизированных библиотек)

# %% [markdown]
# ### 10. Обязательно ли использовать Jupyter Notebook для анализа данных?
#
# **Нет, не обязательно.** Jupyter Notebook — это лишь один из инструментов. Существуют альтернативы:
#
# 1. **Интегрированные среды разработки (IDE)**:
#    - PyCharm (с плагинами для анализа данных)
#    - VS Code (с расширениями для Python и Jupyter)
#    - Spyder (специализированная для науки о данных)
#
# 2. **Другие ноутбуки**:
#    - RStudio (для языка R)
#    - Apache Zeppelin
#    - Databricks Notebook
#
# 3. **Командная строка + скрипты**
# 4. **Облачные платформы**:
#    - Google Colab (аналог Jupyter в облаке)
#    - Kaggle Kernels
#    - Amazon SageMaker
#
# 5. **Специализированные инструменты**:
#    - Tableau (визуализация)
#    - Power BI
#    - RapidMiner
#
# **Выбор инструмента зависит от:**
# - Сложности проекта
# - Предпочтений команды
# - Требований к воспроизводимости
# - Необходимости совместной работы
# - Требований к производительности

# %% [markdown]
# ## Заключение
#
# В ходе лабораторной работы:
# 1. Настроена рабочая среда для анализа данных
# 2. Изучены основные инструменты (GitHub, Google Colab, Jupyter Notebook)
# 3. Освоены принципы работы с Markdown
# 4. Получены практические навыки создания отчетов в Jupyter Notebook
# 5. Изучены теоретические основы анализа данных
#
# Рабочая среда готова к выполнению последующих лабораторных работ по анализу данных.

# %% [markdown]
# ## Ссылки и ресурсы
#
# 1. [Мой форк репозитория](https://github.com/sofiapautova29-maker/dap-2024)
# 2. [Оригинальный репозиторий](https://github.com/chebotarevsa/dap-2024)
# 3. [Google Colab](https://colab.research.google.com/)
# 4. [Документация Jupyter Notebook](https://jupyter-notebook.readthedocs.io/)
# 5. [Markdown руководство](https://www.markdownguide.org/)
# 6. [Pandas документация](https://pandas.pydata.org/docs/)

# %%
# Финальное сообщение
print("=" * 60)
print("ЛАБОРАТОРНАЯ РАБОТА №1 ВЫПОЛНЕНА УСПЕШНО!")
print("=" * 60)
print(f"Студент: Паутова Софья")
print(f"Группа: УСИС-25-4")
print(f"GitHub: sofiapautova29-maker")
print("=" * 60)
# Out:
# Исходные данные:
#         Имя Цвет_глаз Образование
# 0      Анна     карие    бакалавр
# 1     Борис   голубые     магистр
# 2  Виктория   зеленые       школа
#
# One-Hot Encoding для цвета глаз:
#    глаза_голубые  глаза_зеленые  глаза_карие
# 0          False          False         True
# 1           True          False        False
# 2          False           True        False
#
# Label Encoding для образования:
#         Имя Образование  Образование_код
# 0      Анна    бакалавр                2
# 1     Борис     магистр                3
# 2  Виктория       школа                1
# ...
# ЛАБОРАТОРНАЯ РАБОТА №1 ВЫПОЛНЕНА УСПЕШНО!
# ...
# Студент: Паутова Софья
# Группа: УСИС-25-4
# GitHub: sofiapautova29-maker
# ...

# %% [markdown]
# # Лабораторная работа  №1. Подготовка среды для анализа данных

# %% [markdown]
# **Выполнила**: Паутова Софья
#
# **Группа**: УСИС-25-4
#
# **Цель работы**: Настройка рабочей среды для анализа данных с использованием GitHub и Google Colab, изучение основных инструментов и принципов работы в Jupyter Notebook.
#
# # Выполненные задачи:
# # 1. Создание учетной записи GitHub
# Учетная запись GitHub успешно создана с логином: **sofiapautova29-maker**
#
# # 2. Форк репозитория
# Выполнен форк оригинального репозитория:
# - Оригинал: https://github.com/chebotarevsa/dap-2024
# - Мой форк: https://github.com/sofiapautova29-maker/dap-2024
#
# # 3. Создание учетной записи в Google Colab
# Учетная запись Google Colab создана и привязана к аккаунту Google.
#
# # 4. Настройка интеграции Google Colab и GitHub
# Интеграция настроена через:
# 1. Авторизацию в GitHub из Google Colab
# 2. Предоставление необходимых разрешений
# 3. Настройку сохранения notebook'ов напрямую в репозиторий
#
# **Результат:** Возможность сохранения этого файла напрямую в GitHub через меню "Файл → Сохранить копию на GitHub"
#
# # 5. Создание отчета в Google Colab
# Данный отчет создан в формате Jupyter Notebook с использованием:
# # - Markdown ячеек для оформления текста
# # - Кодовых ячеек для демонстрации примеров
# # - Заголовков различных уровней
# # - Форматированного текста
#
# # 6. Сохранение отчета в репозиторий
# Файл будет сохранен в директории `./les01` моего репозитория GitHub.
#
# # 7. Создание Pull Request
# # После сохранения файла будет создан Pull Request в оригинальный репозиторий с названием:
# # **"1 УСИС-25-4 Паутова Софья"**
#
# # 8. Сдача работы
#
# Работа сдана в системе "Пегас" со ссылкой на созданный Pull Request.
#
# # Ответы на контрольные вопросы
#
# # 1. Типы ячеек в Jupyter Notebook
#
# В Jupyter Notebook существуют три основных типа ячеек:
# 1. Code cells (ячейки кода) — для написания и выполнения программного кода
# 2. Markdown cells (текстовые ячейки) — для оформления текста с использованием Markdown
# 3. Raw cells (сырые ячейки) — для неформатированного текста
#
# # 2. Как с помощью Markdown сформировать иерархический список?
# # Используя отступы и различные маркеры:
#
# # ```markdown
# # - Элемент 1
# #   - Подэлемент 1.1
# #     - Подподэлемент 1.1.1
# #   - Подэлемент 1.2
# # - Элемент 2
# # ```
#
# # **Пример:**
# # - Анализ данных
# #   - Сбор данных
# #     - Из API
# #     - Из базы данных
# #   - Очистка данных
# # - Визуализация
#
# # 3. Как с помощью Markdown оформить цитату?
# # Используя символ `>`:
#
# # ```markdown
# # > Это обычная цитата.
# # > Она может занимать несколько строк.
#
# # >> Это вложенная цитата.
# # >
# # > Возврат к основному уровню.
# # ```
#
#
# # > *Пример цитаты:*
# # > "Данные — это новая нефть."
# # > — Клайв Хамби
#
# # 4. Как в текстовую ячейку вставить отформатированный блок кода?
# # С помощью тройных обратных кавычек:
# #
# # ````markdown
# # ```python
# # # Пример кода на Python
# # def hello():
# #     print("Hello, World!")
# #
# # hello()
# # ```
# # ````
#
# # 5. Сколько уровней заголовка существует в Markdown?
# # В Markdown существует **6 уровней заголовков**:
#
# # ```markdown
# # # Заголовок 1 уровня (самый крупный)
# # ## Заголовок 2 уровня
# # ### Заголовок 3 уровня
# # #### Заголовок 4 уровня
# # ##### Заголовок 5 уровня
# # ###### Заголовок 6 уровня (самый мелкий)
# # ```
#
# # 6. Шаги процесса анализа данных
#
# # Основные шаги процесса анализа данных по методологии CRISP-DM:
#
# # 1. Business Understanding (Понимание бизнес-задачи)
# # 2. Data Understanding (Изучение данных)
# # 3. Data Preparation (Подготовка данных)
# # 4. Modeling (Моделирование)
# # 5. Evaluation (Оценка)
# # 6. Deployment (Внедрение)
#
# # **Подробно о Data Preparation:**
# # Это критически важный этап, занимающий до 80% времени анализа. Включает:
# # - **Очистку данных**: удаление дубликатов, обработка пропусков и выбросов
# # - **Трансформацию**: нормализация, масштабирование, кодирование категориальных переменных
# # - **Создание признаков**: генерация новых переменных на основе существующих
# # - **Разделение данных**: на обучающую, валидационную и тестовую выборки
# #
# # Качество подготовки данных напрямую определяет успех всего проекта анализа.
#
# # 7. Типы данных
#
# # Основные типы данных в анализе:
#
# 1. **Числовые данные**
#     - Дискретные (целые числа)
#     - Непрерывные (вещественные числа)
#
# 2. **Категориальные данные**
#   - Номинальные (без порядка: цвета, города)
#   - Порядковые (с естественным порядком: уровни образования)
#
# 3. **Текстовые данные**
# 4. **Временные ряды**
# 5. **Геопространственные данные**
#
# # **Подробно о категориальных данных:**
# # Категориальные данные представляют качественные характеристики объектов. Особенности:
# # - **Номинальные данные**: нет математического порядка (пример: цвета светофора)
# # - **Порядковые данные**: есть естественный порядок (пример: уровни образования: школа < бакалавр < магистр)
#
# # **Методы обработки:**
# # - One-Hot Encoding (для номинальных данных)
# # - Label Encoding (для порядковых данных)
# # - Target Encoding
#
# # **Пример в Python:**
#
#
# # Пример работы с категориальными данными
# import pandas as pd
#
# # Создание датафрейма с категориальными данными
# cat_data = pd.DataFrame({
#     'Имя': ['Анна', 'Борис', 'Виктория'],
#     'Цвет_глаз': ['карие', 'голубые', 'зеленые'],  # номинальные
#     'Образование': ['бакалавр', 'магистр', 'школа']  # порядковые
# })
#
# print("Исходные данные:")
# print(cat_data)
#
# # One-Hot Encoding для номинальных данных
# eye_dummies = pd.get_dummies(cat_data['Цвет_глаз'], prefix='глаза')
# print("\nOne-Hot Encoding для цвета глаз:")
# print(eye_dummies)
#
# # Label Encoding для порядковых данных (вручную)
# education_order = {'школа': 1, 'бакалавр': 2, 'магистр': 3}
# cat_data['Образование_код'] = cat_data['Образование'].map(education_order)
# print("\nLabel Encoding для образования:")
# print(cat_data[['Имя', 'Образование', 'Образование_код']])
#
#
# # 8. Что такое Jupyter Notebook, для чего используется?
#
# # **Jupyter Notebook** — это интерактивная веб-среда для создания и совместного использования документов, содержащих:
# # - Живой код (Python, R, Julia и др.)
# # - Визуализации (графики, диаграммы)
# # - Текстовые пояснения (Markdown, LaTeX)
# # - Мультимедиа
#
# # **Основные применения:**
# # 1. **Анализ данных и машинное обучение**
# # 2. **Научные исследования и вычисления**
# # 3. **Прототипирование и разработка**
# # 4. **Обучение и преподавание**
# # 5. **Создание воспроизводимых отчетов**
# # 6. **Интерактивная визуализация**
#
# # **Преимущества:**
# # - Интерактивность (код выполняется и результат виден сразу)
# # - Воспроизводимость (легко повторить анализ)
# # - Документирование (код и объяснения в одном месте)
# # - Поддержка различных языков
#
# # 9. Почему Python популярен для анализа данных?
#
# Python стал стандартом де-факто для анализа данных благодаря:
#
# # 1. **Богатой экосистеме библиотек**:
# #    - `pandas` — обработка табличных данных
# #    - `numpy` — численные вычисления
# #    - `matplotlib`, `seaborn` — визуализация
# #    - `scikit-learn` — машинное обучение
# #    - `tensorflow`, `pytorch` — глубокое обучение
# # 2. **Простоте и читаемости** синтаксиса
# # 3. **Большому и активному сообществу**
# # 4. **Кроссплатформенности** (работает везде)
# # 5. **Бесплатности** и открытости
# # 6. **Интеграции** с другими инструментами и языками
# # 7. **Поддержке различных парадигм** программирования
# # 8. **Хорошей производительности** (за счет оптимизированных библиотек)
#
# # 10. Обязательно ли использовать Jupyter Notebook для анализа данных?
#
# # **Нет, не обязательно.** Jupyter Notebook — это лишь один из инструментов. Существуют альтернативы:
#
# # 1. **Интегрированные среды разработки (IDE)**:
# #    - PyCharm (с плагинами для анализа данных)
# #    - VS Code (с расширениями для Python и Jupyter)
# #    - Spyder (специализированная для науки о данных)
#
# # 2. **Другие ноутбуки**:
# #    - RStudio (для языка R)
# #    - Apache Zeppelin
# #    - Databricks Notebook
#
# # 3. **Командная строка + скрипты**
# # 4. **Облачные платформы**:
# #    - Google Colab (аналог Jupyter в облаке)
# #    - Kaggle Kernels
# #    - Amazon SageMaker
#
# # 5. **Специализированные инструменты**:
# #    - Tableau (визуализация)
# #    - Power BI
# #    - RapidMiner
#
# # **Выбор инструмента зависит от:**
# # - Сложности проекта
# # - Предпочтений команды
# # - Требований к воспроизводимости
# # - Необходимости совместной работы
# # - Требований к производительности
#
# # Заключение
#
# # В ходе лабораторной работы:
# # 1. Настроена рабочая среда для анализа данных
# # 2. Изучены основные инструменты (GitHub, Google Colab, Jupyter Notebook)
# # 3. Освоены принципы работы с Markdown
# # 4. Получены практические навыки создания отчетов в Jupyter Notebook
# # 5. Изучены теоретические основы анализа данных
#
# # Рабочая среда готова к выполнению последующих лабораторных работ по анализу данных.
#
# # Ссылки и ресурсы
# # 1. [Мой форк репозитория](https://github.com/sofiapautova29-maker/dap-2024)
# # 2. [Оригинальный репозиторий](https://github.com/chebotarevsa/dap-2024)
# # 3. [Google Colab](https://colab.research.google.com/)
# # 4. [Документация Jupyter Notebook](https://jupyter-notebook.readthedocs.io/)
# # 5. [Markdown руководство](https://www.markdownguide.org/)
# # 6. [Pandas документация](https://pandas.pydata.org/docs/)
